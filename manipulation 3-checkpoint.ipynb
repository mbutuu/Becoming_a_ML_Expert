# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
 data = pd.read_csv("cars.csv")

# %%
 data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0     Mazda    Red         25987      4     3450000
# 1    Toyota  Black        123907      4      950000
# 2     Tesla   Grey         85723      2    12450000
# 3   V.Wagon   Blue        111634      4     2500000
# 4  Peugeout  White         99561      4     2780000
# 5       BMW  Black         41007      2     7550000
# 6  Mercedes  Black         39765      2     6000000
# 7    Subaru    Red        145456      4     3270000
# 8     Lexus  Cream         75636      4    14670000
# 9   Morbius  Black         23089      2     5500000

# %%
seats = pd.Series([5,5,2,5,5,5,2,2,5,2])
data["Seats"]= seats

# %%
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats
# 0     Mazda    Red         25987      4     3450000      5
# 1    Toyota  Black        123907      4      950000      5
# 2     Tesla   Grey         85723      2    12450000      2
# 3   V.Wagon   Blue        111634      4     2500000      5
# 4  Peugeout  White         99561      4     2780000      5
# 5       BMW  Black         41007      2     7550000      5
# 6  Mercedes  Black         39765      2     6000000      2
# 7    Subaru    Red        145456      4     3270000      2
# 8     Lexus  Cream         75636      4    14670000      5
# 9   Morbius  Black         23089      2     5500000      2

# %%
fuel_consumption = pd.Series([5.4,2.3,5.8,9,4.2,6.3])
data["Fuel_per_100KM"] = fuel_consumption
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
# 6  Mercedes  Black         39765      2     6000000      2             NaN
# 7    Subaru    Red        145456      4     3270000      2             NaN
# 8     Lexus  Cream         75636      4    14670000      5             NaN
# 9   Morbius  Black         23089      2     5500000      2             NaN

# %%
data["Fuel_per_100KM"] = data["Fuel_per_100KM"].fillna(data["Fuel_per_100KM"].mean())
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 9   Morbius  Black         23089      2     5500000      2             5.5

# %%
data["Total_fuel(L)"] = data["Odometer(KM)"]/100 * data["Fuel_per_100KM"]
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 9   Morbius  Black         23089      2     5500000      2             5.5
#
#    Total_fuel  Total_fuel(L)
# 0    1403.298       1403.298
# 1    2849.861       2849.861
# 2    4971.934       4971.934
# ...

# %%
data["No_of_wheels"] = 4
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 9   Morbius  Black         23089      2     5500000      2             5.5
#
#    Total_fuel  Total_fuel(L)  No_of_wheels
# 0    1403.298       1403.298             4
# 1    2849.861       2849.861             4
# ...

# %%
data.dtypes
# Out:
# Car                object
# Colour             object
# Odometer(KM)        int64
# Doors               int64
# Price(KSh)          int64
# Seats               int64
# Fuel_per_100KM    float64
# Total_fuel        float64
# Total_fuel(L)     float64
# No_of_wheels        int64
# dtype: object

# %%
data = data.drop("Total_fuel(L)", axis=1)

# %%
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 9   Morbius  Black         23089      2     5500000      2             5.5
#
#    No_of_wheels
# 0             4
# 1             4
# 2             4
# 3             4
# 4             4
# 5             4
# 6             4
# ...

# %%
data["Max_load"] = pd.Series([600,750,1200,750,650,400])
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 9   Morbius  Black         23089      2     5500000      2             5.5
#
#    No_of_wheels  Max_load
# 0             4     600.0
# 1             4     750.0
# 2             4    1200.0
# 3             4     750.0
# ...

# %%
data["Max_load"] = data["Max_load"].fillna(data["Max_load"].mean())
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 9   Morbius  Black         23089      2     5500000      2             5.5
#
#    No_of_wheels  Max_load
# 0             4     600.0
# 1             4     750.0
# 2             4    1200.0
# 3             4     750.0
# ...

# %%
data.sample(frac=1)
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 5       BMW  Black         41007      2     7550000      5             6.3
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 1    Toyota  Black        123907      4      950000      5             2.3
# 9   Morbius  Black         23089      2     5500000      2             5.5
#
#    No_of_wheels  Max_load
# 5             4     400.0
# 0             4     600.0
# 6             4     725.0
# 3             4     750.0
# ...

# %%
data_shuffled = data.sample(frac=1)
data = data_shuffled.sample(frac=0)

# %%
data
# Out:
# Empty DataFrame
# Columns: [Car, Colour, Odometer(KM), Doors, Price(KSh), Seats, Fuel_per_100KM, No_of_wheels, Max_load]
# Index: []

# %%
data_shuffled
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 8     Lexus  Cream         75636      4    14670000      5             5.5
# 3   V.Wagon   Blue        111634      4     2500000      5             9.0
# 7    Subaru    Red        145456      4     3270000      2             5.5
# 6  Mercedes  Black         39765      2     6000000      2             5.5
# 0     Mazda    Red         25987      4     3450000      5             5.4
# 9   Morbius  Black         23089      2     5500000      2             5.5
# 1    Toyota  Black        123907      4      950000      5             2.3
# 2     Tesla   Grey         85723      2    12450000      2             5.8
# 4  Peugeout  White         99561      4     2780000      5             4.2
# 5       BMW  Black         41007      2     7550000      5             6.3
#
#    No_of_wheels  Max_load
# 8             4     725.0
# 3             4     750.0
# 7             4     725.0
# 6             4     725.0
# ...

# %%
data = data_shuffled.reset_index(drop= True, inplace= True)
data

# %%
data_shuffled
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 0     Lexus  Cream         75636      4    14670000      5             5.5
# 1   V.Wagon   Blue        111634      4     2500000      5             9.0
# 2    Subaru    Red        145456      4     3270000      2             5.5
# 3  Mercedes  Black         39765      2     6000000      2             5.5
# 4     Mazda    Red         25987      4     3450000      5             5.4
# 5   Morbius  Black         23089      2     5500000      2             5.5
# 6    Toyota  Black        123907      4      950000      5             2.3
# 7     Tesla   Grey         85723      2    12450000      2             5.8
# 8  Peugeout  White         99561      4     2780000      5             4.2
# 9       BMW  Black         41007      2     7550000      5             6.3
#
#    No_of_wheels  Max_load
# 0             4     725.0
# 1             4     750.0
# 2             4     725.0
# 3             4     725.0
# ...

# %%
data

# %%
data_shuffled.sample(frac=1)
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 2    Subaru    Red        145456      4     3270000      2             5.5
# 3  Mercedes  Black         39765      2     6000000      2             5.5
# 6    Toyota  Black        123907      4      950000      5             2.3
# 0     Lexus  Cream         75636      4    14670000      5             5.5
# 8  Peugeout  White         99561      4     2780000      5             4.2
# 9       BMW  Black         41007      2     7550000      5             6.3
# 5   Morbius  Black         23089      2     5500000      2             5.5
# 7     Tesla   Grey         85723      2    12450000      2             5.8
# 1   V.Wagon   Blue        111634      4     2500000      5             9.0
# 4     Mazda    Red         25987      4     3450000      5             5.4
#
#    No_of_wheels  Max_load
# 2             4     725.0
# 3             4     725.0
# 6             4     750.0
# 0             4     725.0
# ...

# %%
data_shuffled = data_shuffled.sample(frac=1)

# %%
data_shuffled
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)  Seats  Fuel_per_100KM  \
# 7     Tesla   Grey         85723      2    12450000      2             5.8
# 8  Peugeout  White         99561      4     2780000      5             4.2
# 3  Mercedes  Black         39765      2     6000000      2             5.5
# 9       BMW  Black         41007      2     7550000      5             6.3
# 0     Lexus  Cream         75636      4    14670000      5             5.5
# 4     Mazda    Red         25987      4     3450000      5             5.4
# 6    Toyota  Black        123907      4      950000      5             2.3
# 5   Morbius  Black         23089      2     5500000      2             5.5
# 2    Subaru    Red        145456      4     3270000      2             5.5
# 1   V.Wagon   Blue        111634      4     2500000      5             9.0
#
#    No_of_wheels  Max_load
# 7             4    1200.0
# 8             4     650.0
# 3             4     725.0
# 9             4     400.0
# ...

# %%
data_shuffled = data_shuffled.reset_index(drop=True, inplace=True)

# %%
data_shuffled

# %%
    print(data_shuffled)
# Out:
# None

# %%
data

# %%
 data = pd.read_csv("cars.csv")

# %%
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0     Mazda    Red         25987      4     3450000
# 1    Toyota  Black        123907      4      950000
# 2     Tesla   Grey         85723      2    12450000
# 3   V.Wagon   Blue        111634      4     2500000
# 4  Peugeout  White         99561      4     2780000
# 5       BMW  Black         41007      2     7550000
# 6  Mercedes  Black         39765      2     6000000
# 7    Subaru    Red        145456      4     3270000
# 8     Lexus  Cream         75636      4    14670000
# 9   Morbius  Black         23089      2     5500000

# %%
data["Odometer(KM)"] = data["Odometer(KM)"].apply(lambda x:x /1.6)
data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0     Mazda    Red     16241.875      4     3450000
# 1    Toyota  Black     77441.875      4      950000
# 2     Tesla   Grey     53576.875      2    12450000
# 3   V.Wagon   Blue     69771.250      4     2500000
# 4  Peugeout  White     62225.625      4     2780000
# 5       BMW  Black     25629.375      2     7550000
# 6  Mercedes  Black     24853.125      2     6000000
# 7    Subaru    Red     90910.000      4     3270000
# 8     Lexus  Cream     47272.500      4    14670000
# 9   Morbius  Black     14430.625      2     5500000
