# %%
import pandas as pd

# %%
colours = pd.Series(["Blue", "Black", "White"])

# %%
colours
# Out:
# 0     Blue
# 1    Black
# 2    White
# dtype: object

# %%
cars = pd.Series(["Audi", "Mercedes", "BMW"])

# %%
cars
# Out:
# 0        Audi
# 1    Mercedes
# 2         BMW
# dtype: object

# %%
combination = pd.crosstab(cars,colours)

# %%
combination
# Out:
# col_0     Black  Blue  White
# row_0
# Audi          0     1      0
# BMW           0     0      1
# Mercedes      1     0      0

# %%
result = pd.DataFrame({'Cars': cars, 'Colours': colours})

# %%
result
# Out:
#        Cars Colours
# 0      Audi    Blue
# 1  Mercedes   Black
# 2       BMW   White

# %%
car_data = pd.read_csv("cars.csv")
car_data
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0     Mazda    Red         25987      4     3450000
# 1    Toyota  Black        123907      4      950000
# 2     Tesla   Grey         85723      2    12450000
# 3   V.Wagon   Blue        111634      4     2500000
# 4  Peugeout  White         99561      4     2780000
# 5       BMW  Black         41007      2     7550000
# 6  Mercedes  Black         39765      2     6000000
# 7    Subaru    Red        145456      4     3270000
# 8     Lexus  Cream         75636      4    14670000
# 9   Morbius  Black         23089      2     5500000

# %%
car_data.dtypes
# Out:
# Car             object
# Colour          object
# Odometer(KM)     int64
# Doors            int64
# Price(KSh)       int64
# dtype: object

# %%
car_data.describe()
# Out:
#         Odometer(KM)      Doors    Price(KSh)
# count      10.000000  10.000000  1.000000e+01
# mean    77176.500000   3.200000  5.912000e+06
# std     43286.264602   1.032796  4.489776e+06
# min     23089.000000   2.000000  9.500000e+05
# 25%     40075.500000   2.000000  2.902500e+06
# 50%     80679.500000   4.000000  4.475000e+06
# 75%    108615.750000   4.000000  7.162500e+06
# max    145456.000000   4.000000  1.467000e+07

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           10 non-null     object
#  1   Colour        10 non-null     object
#  2   Odometer(KM)  10 non-null     int64
#  3   Doors         10 non-null     int64
#  4   Price(KSh)    10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
numbers = pd.Series([1,3,4,6,7,9,23])
no_mean = numbers.mean()

# %%
no_mean
# Out:
# np.float64(7.571428571428571)

# %%
no_sum = numbers.sum()
no_sum
# Out:
# np.int64(53)

# %%
car_data.columns
# Out:
# Index(['Car', 'Colour', 'Odometer(KM)', 'Doors', 'Price(KSh)'], dtype='object')

# %%
len(car_data)
# Out:
# 10

# %%
car_data.head()
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0     Mazda    Red         25987      4     3450000
# 1    Toyota  Black        123907      4      950000
# 2     Tesla   Grey         85723      2    12450000
# 3   V.Wagon   Blue        111634      4     2500000
# 4  Peugeout  White         99561      4     2780000

# %%
car_data.head(6)
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0     Mazda    Red         25987      4     3450000
# 1    Toyota  Black        123907      4      950000
# 2     Tesla   Grey         85723      2    12450000
# 3   V.Wagon   Blue        111634      4     2500000
# 4  Peugeout  White         99561      4     2780000
# 5       BMW  Black         41007      2     7550000

# %%
car_data.head(7)
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0     Mazda    Red         25987      4     3450000
# 1    Toyota  Black        123907      4      950000
# 2     Tesla   Grey         85723      2    12450000
# 3   V.Wagon   Blue        111634      4     2500000
# 4  Peugeout  White         99561      4     2780000
# 5       BMW  Black         41007      2     7550000
# 6  Mercedes  Black         39765      2     6000000

# %%
car_data.tail()
# Out:
#         Car Colour  Odometer(KM)  Doors  Price(KSh)
# 5       BMW  Black         41007      2     7550000
# 6  Mercedes  Black         39765      2     6000000
# 7    Subaru    Red        145456      4     3270000
# 8     Lexus  Cream         75636      4    14670000
# 9   Morbius  Black         23089      2     5500000

# %%
car_data.loc[3]
# Out:
# Car             V.Wagon
# Colour             Blue
# Odometer(KM)     111634
# Doors                 4
# Price(KSh)      2500000
# Name: 3, dtype: object

# %%
car_data.loc[:3]
# Out:
#        Car Colour  Odometer(KM)  Doors  Price(KSh)
# 0    Mazda    Red         25987      4     3450000
# 1   Toyota  Black        123907      4      950000
# 2    Tesla   Grey         85723      2    12450000
# 3  V.Wagon   Blue        111634      4     2500000

# %%
car_data.loc[1:3]
# Out:
#        Car Colour  Odometer(KM)  Doors  Price(KSh)
# 1   Toyota  Black        123907      4      950000
# 2    Tesla   Grey         85723      2    12450000
# 3  V.Wagon   Blue        111634      4     2500000

# %%
car_data.iloc[2]
# Out:
# Car                Tesla
# Colour              Grey
# Odometer(KM)       85723
# Doors                  2
# Price(KSh)      12450000
# Name: 2, dtype: object

# %%
car_data.iloc[3]
# Out:
# Car             V.Wagon
# Colour             Blue
# Odometer(KM)     111634
# Doors                 4
# Price(KSh)      2500000
# Name: 3, dtype: object

# %%
car_data["Odometer(KM)"]
# Out:
# 0     25987
# 1    123907
# 2     85723
# 3    111634
# 4     99561
# 5     41007
# 6     39765
# 7    145456
# 8     75636
# 9     23089
# Name: Odometer(KM), dtype: int64

# %%
car_data["Odometer(KM)"].mean()
# Out:
# np.float64(77176.5)

# %%
car_data["Odometer(KM)"] >= 100000
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Odometer(KM), dtype: bool

# %%
car_data[car_data["Odometer(KM)"] >= 100000]
# Out:
#        Car Colour  Odometer(KM)  Doors  Price(KSh)
# 1   Toyota  Black        123907      4      950000
# 3  V.Wagon   Blue        111634      4     2500000
# 7   Subaru    Red        145456      4     3270000

# %%
pd.crosstab(car_data["Car"], car_data["Doors"])
# Out:
# Doors     2  4
# Car
# BMW       1  0
# Lexus     0  1
# Mazda     0  1
# Mercedes  1  0
# Morbius   1  0
# Peugeout  0  1
# Subaru    0  1
# Tesla     1  0
# Toyota    0  1
# V.Wagon   0  1

# %%
car_data.groupby("Car").mean(numeric_only=True)
# Out:
#           Odometer(KM)  Doors  Price(KSh)
# Car
# BMW            41007.0    2.0   7550000.0
# Lexus          75636.0    4.0  14670000.0
# Mazda          25987.0    4.0   3450000.0
# Mercedes       39765.0    2.0   6000000.0
# Morbius        23089.0    2.0   5500000.0
# Peugeout       99561.0    4.0   2780000.0
# Subaru        145456.0    4.0   3270000.0
# Tesla          85723.0    2.0  12450000.0
# Toyota        123907.0    4.0    950000.0
# V.Wagon       111634.0    4.0   2500000.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
car_data["Odometer(KM)"].plot(kind= "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_data["Price(KSh)"].plot()
# Out:
# <Axes: >

# %%
carrs = pd.read_csv("car-sales.csv")
carrs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carrs["Price"] = carrs["Price"].replace({"\\$":"",",":""}, regex=True).astype(float)

# %%
carrs
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
carrs["Make"] = carrs["Make"].str.lower()

# %%
carrs
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
pd.crosstab(carrs["Make"], carrs["Doors"])
# Out:
# Doors   3  4  5
# Make
# bmw     0  0  1
# honda   0  3  0
# nissan  0  2  0
# toyota  1  3  0

# %%
mcd = pd.read_csv("missing_car_data.csv")

# %%
mcd
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
mcd["Price"] = mcd["Price"].replace({"\\$":"",",":""}, regex= True).astype(float)

# %%
mcd
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 2  Toyota   Blue       NaN    3.0   7000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 5  Toyota  Green       NaN    4.0   4500.0
# 6   Honda    NaN       NaN    4.0   7500.0
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   9700.0

# %%
mcd["Seats"]= 5

# %%
mcd["Engine_size"]= pd.Series([1.5, 1.7, 4,5, 3.8, 4.0])

# %%
mcd["Price_per_KM"] = mcd["Price"]/mcd["Odometer"]
mcd
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Engine_size  Price_per_KM
# 0  Toyota  White  150043.0    4.0   4000.0      5          1.5      0.026659
# 1   Honda    Red   87899.0    4.0   5000.0      5          1.7      0.056883
# 2  Toyota   Blue       NaN    3.0   7000.0      5          4.0           NaN
# 3     BMW  Black   11179.0    5.0  22000.0      5          5.0      1.967976
# 4  Nissan  White  213095.0    4.0   3500.0      5          3.8      0.016425
# 5  Toyota  Green       NaN    4.0   4500.0      5          4.0           NaN
# 6   Honda    NaN       NaN    4.0   7500.0      5          NaN           NaN
# 7   Honda   Blue       NaN    4.0      NaN      5          NaN           NaN
# 8  Toyota  White   60000.0    NaN      NaN      5          NaN           NaN
# 9     NaN  White   31600.0    4.0   9700.0      5          NaN      0.306962

# %%
mcd["Price_per_KM"].drop(index=1)
# Out:
# 0    0.026659
# 2         NaN
# 3    1.967976
# 4    0.016425
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9    0.306962
# Name: Price_per_KM, dtype: float64

# %%
mcd
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Engine_size  Price_per_KM
# 0  Toyota  White  150043.0    4.0   4000.0      5          1.5      0.026659
# 1   Honda    Red   87899.0    4.0   5000.0      5          1.7      0.056883
# 2  Toyota   Blue       NaN    3.0   7000.0      5          4.0           NaN
# 3     BMW  Black   11179.0    5.0  22000.0      5          5.0      1.967976
# 4  Nissan  White  213095.0    4.0   3500.0      5          3.8      0.016425
# 5  Toyota  Green       NaN    4.0   4500.0      5          4.0           NaN
# 6   Honda    NaN       NaN    4.0   7500.0      5          NaN           NaN
# 7   Honda   Blue       NaN    4.0      NaN      5          NaN           NaN
# 8  Toyota  White   60000.0    NaN      NaN      5          NaN           NaN
# 9     NaN  White   31600.0    4.0   9700.0      5          NaN      0.306962

# %%
mcd = mcd.drop("Price_per_KM", axis=1)
mcd
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Engine_size
# 0  Toyota  White  150043.0    4.0   4000.0      5          1.5
# 1   Honda    Red   87899.0    4.0   5000.0      5          1.7
# 2  Toyota   Blue       NaN    3.0   7000.0      5          4.0
# 3     BMW  Black   11179.0    5.0  22000.0      5          5.0
# 4  Nissan  White  213095.0    4.0   3500.0      5          3.8
# 5  Toyota  Green       NaN    4.0   4500.0      5          4.0
# 6   Honda    NaN       NaN    4.0   7500.0      5          NaN
# 7   Honda   Blue       NaN    4.0      NaN      5          NaN
# 8  Toyota  White   60000.0    NaN      NaN      5          NaN
# 9     NaN  White   31600.0    4.0   9700.0      5          NaN

# %%
mcd.sample(frac=1)
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Engine_size
# 6   Honda    NaN       NaN    4.0   7500.0      5          NaN
# 9     NaN  White   31600.0    4.0   9700.0      5          NaN
# 3     BMW  Black   11179.0    5.0  22000.0      5          5.0
# 0  Toyota  White  150043.0    4.0   4000.0      5          1.5
# 1   Honda    Red   87899.0    4.0   5000.0      5          1.7
# 2  Toyota   Blue       NaN    3.0   7000.0      5          4.0
# 4  Nissan  White  213095.0    4.0   3500.0      5          3.8
# 5  Toyota  Green       NaN    4.0   4500.0      5          4.0
# 8  Toyota  White   60000.0    NaN      NaN      5          NaN
# 7   Honda   Blue       NaN    4.0      NaN      5          NaN

# %%
mcc = mcd.sample(frac=1)

# %%
mcc
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Engine_size
# 0   Honda    NaN       NaN    4.0   7500.0      5          NaN
# 1  Toyota  White  150043.0    4.0   4000.0      5          1.5
# 2  Nissan  White  213095.0    4.0   3500.0      5          3.8
# 3  Toyota   Blue       NaN    3.0   7000.0      5          4.0
# 4     NaN  White   31600.0    4.0   9700.0      5          NaN
# 5     BMW  Black   11179.0    5.0  22000.0      5          5.0
# 6   Honda   Blue       NaN    4.0      NaN      5          NaN
# 7   Honda    Red   87899.0    4.0   5000.0      5          1.7
# 8  Toyota  Green       NaN    4.0   4500.0      5          4.0
# 9  Toyota  White   60000.0    NaN      NaN      5          NaN

# %%
mcc.reset_index(drop= True, inplace=True)

# %%
mcc
# Out:
#      Make Colour  Odometer  Doors    Price  Seats  Engine_size
# 0   Honda    NaN       NaN    4.0   7500.0      5          NaN
# 1  Toyota  White  150043.0    4.0   4000.0      5          1.5
# 2  Nissan  White  213095.0    4.0   3500.0      5          3.8
# 3  Toyota   Blue       NaN    3.0   7000.0      5          4.0
# 4     NaN  White   31600.0    4.0   9700.0      5          NaN
# 5     BMW  Black   11179.0    5.0  22000.0      5          5.0
# 6   Honda   Blue       NaN    4.0      NaN      5          NaN
# 7   Honda    Red   87899.0    4.0   5000.0      5          1.7
# 8  Toyota  Green       NaN    4.0   4500.0      5          4.0
# 9  Toyota  White   60000.0    NaN      NaN      5          NaN

# %%
mcc["Odometer"] = mcc["Odometer"].apply(lambda x:x/1.6)
mcc = mcc.rename(columns={"Odometer":"Odometer(M)"})

# %% [markdown]
# mcc

# %%
mcc
# Out:
#      Make Colour   Odometer(M)  Doors    Price  Seats  Engine_size
# 0   Honda    NaN           NaN    4.0   7500.0      5          NaN
# 1  Toyota  White  36631.591797    4.0   4000.0      5          1.5
# 2  Nissan  White  52025.146484    4.0   3500.0      5          3.8
# 3  Toyota   Blue           NaN    3.0   7000.0      5          4.0
# 4     NaN  White   7714.843750    4.0   9700.0      5          NaN
# 5     BMW  Black   2729.248047    5.0  22000.0      5          5.0
# 6   Honda   Blue           NaN    4.0      NaN      5          NaN
# 7   Honda    Red  21459.716797    4.0   5000.0      5          1.7
# 8  Toyota  Green           NaN    4.0   4500.0      5          4.0
# 9  Toyota  White  14648.437500    NaN      NaN      5          NaN
